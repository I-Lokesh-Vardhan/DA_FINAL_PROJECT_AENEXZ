# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mlt

# %%
df = pd.read_csv("WA_Fn-UseC_-HR-Employee-Attrition.csv")
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
print("Number of rows :",df.shape[0])
print("Number of columns :",df.shape[1])
# Out:
# Number of rows : 1470
# Number of columns : 35

# %%
df.columns.tolist()
# Out:
# ['Age',
#  'Attrition',
#  'BusinessTravel',
#  'DailyRate',
#  'Department',
#  'DistanceFromHome',
#  'Education',
#  'EducationField',
#  'EmployeeCount',
#  'EmployeeNumber',
#  'EnvironmentSatisfaction',
#  'Gender',
#  'HourlyRate',
#  'JobInvolvement',
#  'JobLevel',
#  'JobRole',
#  'JobSatisfaction',
#  'MaritalStatus',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'Over18',
#  'OverTime',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StandardHours',
#  'StockOptionLevel',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   str
#  2   BusinessTravel            1470 non-null   str
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   str
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   str
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   str
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
# checking for missing values
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
print("Total missing values:",df.isnull().sum().sum())
# Out:
# Total missing values: 0

# %% [raw]
# The dataset was checked for any missing values.
# No missing values were identified, so no deletion is required.

# %%
# Checking duplicate rows
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# checking for unique employee identifier
df["EmployeeNumber"].duplicated().sum()
# Out:
# np.int64(0)

# %%
numerical_columns = df.select_dtypes(include=["int64","float64"]).columns.tolist()
categorical_columns = df.select_dtypes(include=["object","string"]).columns.tolist()
print("Number of numercial columns :",len(numerical_columns))
print("Number of categorical columns :",len(categorical_columns))
# Out:
# Number of numercial columns : 24
# Number of categorical columns : 8

# %%
# checking unique values
for column in df.columns:
    print(column,":", df[column].unique())
# Out:
# Age : [41 49 37 33 27 32 59 30 38 36 35 29 31 34 28 22 53 24 21 42 44 46 39 43
#  50 26 48 55 45 56 23 51 40 54 58 20 25 19 57 52 47 18 60]
# Attrition : <StringArray>
# ['Yes', 'No']
# Length: 2, dtype: str
# BusinessTravel : <StringArray>
# ['Travel_Rarely', 'Travel_Frequently', 'Non-Travel']
# Length: 3, dtype: str
# DailyRate : [1102  279 1373 1392  591 1005 1324 1358  216 1299  809  153  670 1346
#   103 1389  334 1123 1219  371  673 1218  419  391  699 1282 1125  691
#   477  705  924 1459  125  895  813 1273  869  890  852 1141  464 1240
#  1357  994  721 1360 1065  408 1211 1229  626 1434 1488 1097 1443  515
#   853 1142  655 1115  427  653  989 1435 1223  836 1195 1339  664  318
#  1225 1328 1082  548  132  746  776  193  397  945 1214  111  573 1153
#  1400  541  432  288  669  530  632 1334  638 1093 1217 1353  120  682
#   489  807  827  871  665 1040 1420  240 1280  534 1456  658  142 1127
#  1031 1189 1354 1467  922  394 1312  750  441  684  249  841  147  528
# ...

# %%
# Identifying constant columns
constant_columns=[
    column for column in df.columns
    if df[column].nunique() == 1
]
print(constant_columns)
# Out:
# ['EmployeeCount', 'Over18', 'StandardHours']

# %%
# removing constant columns
df.drop(
    columns=[
        "EmployeeCount",
        "Over18",
        "StandardHours"
    ], inplace = True
)
df.shape
# Out:
# (1470, 32)

# %% [raw]
# Three zero-variance variables - 'EmployeeCount', 'Over18 ', and 'StandardHours' were removed because each of the columns contained the same value from top to bottom.

# %%
# Checking categorical values for inconsistencies
categorical_columns = df.select_dtypes(include = ["object","string"]).columns
for column in categorical_columns:
    print("\n", column)
    print(df[column].value_counts())
# Out:
#  Attrition
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64
#
#  BusinessTravel
# BusinessTravel
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: count, dtype: int64
#
#  Department
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64
#
#  EducationField
# EducationField
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: count, dtype: int64
#
#  Gender
# Gender
# Male      882
# Female    588
# Name: count, dtype: int64
#
#  JobRole
# JobRole
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# ...

# %%
# Checking for white spaces
for column in categorical_columns:
    df[column]= df[column].str.strip()

# %%
for column in categorical_columns:
    print(column, df[column].unique())
# Out:
# Attrition <StringArray>
# ['Yes', 'No']
# Length: 2, dtype: str
# BusinessTravel <StringArray>
# ['Travel_Rarely', 'Travel_Frequently', 'Non-Travel']
# Length: 3, dtype: str
# Department <StringArray>
# ['Sales', 'Research & Development', 'Human Resources']
# Length: 3, dtype: str
# EducationField <StringArray>
# [   'Life Sciences',            'Other',          'Medical',
#         'Marketing', 'Technical Degree',  'Human Resources']
# Length: 6, dtype: str
# Gender <StringArray>
# ['Female', 'Male']
# Length: 2, dtype: str
# JobRole <StringArray>
# [          'Sales Executive',        'Research Scientist',
#      'Laboratory Technician',    'Manufacturing Director',
#  'Healthcare Representative',                   'Manager',
#       'Sales Representative',         'Research Director',
#            'Human Resources']
# Length: 9, dtype: str
# MaritalStatus <StringArray>
# ['Single', 'Married', 'Divorced']
# Length: 3, dtype: str
# OverTime <StringArray>
# ['Yes', 'No']
# ...

# %%
# Checking impossible values 
print("Age range:", df["Age"].min(),"to",df["Age"].max())
print("Monthly Income Range:", df["MonthlyIncome"].min(),"to",df["MonthlyIncome"].max())
print("Distance From Home Range:", df["DistanceFromHome"].min(),"to",df["DistanceFromHome"].max())
print("Years at Company Range:", df["YearsAtCompany"].min(),"to",df["YearsAtCompany"].max())
# Out:
# Age range: 18 to 60
# Monthly Income Range: 1009 to 19999
# Distance From Home Range: 1 to 29
# Years at Company Range: 0 to 40

# %%
# Checking for any negative values
num_df = df.select_dtypes(include=np.number)
negative_counts = (num_df <0).sum()
print(negative_counts[negative_counts >0])
# Out:
# Series([], dtype: int64)

# %%
# Identifying Outliers using IQR
def detect_outliers_IQR(data,column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)

    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = data[(data[column] < lower_bound) | (data[column] > upper_bound)]

    return len(outliers)

# %%
for column in numerical_columns:
    if column in df.columns:
        count = detect_outliers_IQR(df,column)
        if count>0:
            print(column,":",count)
# Out:
# MonthlyIncome : 114
# NumCompaniesWorked : 52
# PerformanceRating : 226
# StockOptionLevel : 85
# TotalWorkingYears : 63
# TrainingTimesLastYear : 238
# YearsAtCompany : 104
# YearsInCurrentRole : 21
# YearsSinceLastPromotion : 107
# YearsWithCurrManager : 14

# %% [raw]
# In this dataset, the above-mentioned variables like MonthlyIncome, YearsAtCompany or TotalWorkingYears contain statistically extreme values. These should be retained, as some senior employees with high income or long tenure are not a data-quality error.

# %%
# Final validation
print("Final shape:", df.shape)
print("Missing values:",df.isnull().sum().sum())
print("Duplicate rows:",df.duplicated().sum())
print("Duplicate Employee IDs:",df["EmployeeNumber"].duplicated().sum())
# Out:
# Final shape: (1470, 32)
# Missing values: 0
# Duplicate rows: 0
# Duplicate Employee IDs: 0

# %%
# Saving the cleaned dataset 
df.to_csv("HR_Employee_Attrition_Cleaned.csv",index = False)
print("Cleaned dataset saved successfully.")
# Out:
# Cleaned dataset saved successfully.

# %% [raw]
# This is the final dataset after performing the data cleaning process.
# We will use this updated dataset for the upcoming project.
